# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
btc_dataframe = pd.read_csv("xrp_usd.csv")
btc_dataframe.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  2021-05-28  0.973952  0.983460  0.847571  0.900148   0.900148  6082828979
# 1  2021-05-29  0.899495  0.939792  0.795070  0.831788   0.831788  5156278121
# 2  2021-05-30  0.831994  0.930127  0.799825  0.906609   0.906609  4077064725
# 3  2021-05-31  0.906384  1.049022  0.882556  1.046584   1.046584  6277821474
# 4  2021-06-01  1.042102  1.099639  0.979337  1.011001   1.011001  5606414479

# %%
btc_dataframe.tail()
# Out:
#            Date      Open      High       Low     Close  Adj Close      Volume
# 361  2022-05-24  0.404681  0.413289  0.393646  0.408713   0.408713  1394251522
# 362  2022-05-25  0.408700  0.412966  0.396760  0.405785   0.405785  1587278448
# 363  2022-05-26  0.405799  0.410119  0.380723  0.393170   0.393170  2091610974
# 364  2022-05-27  0.393076  0.401280  0.378166  0.381787   0.381787  1927217638
# 365  2022-05-28  0.383511  0.387882  0.381774  0.385851   0.385851  1481583744

# %%
x = btc_dataframe["Date"]
y1 = btc_dataframe["Open"]
y2 = btc_dataframe["Close"]

# %%
## create plt figure and plot

plt.figure(figsize=(15,8), dpi=100)

## first subplot

plt.subplot(1,2,1)
plt.plot(x,y1, "r--")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("Open market value - STOCK Daily")


## second subplot

plt.subplot(1,2,2)
plt.plot(x,y2, "b")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("Close market value - STOCK Daily")

plt.show()

# %%
plt.hist(y2, color="red")
plt.xlabel("Price")
plt.title("Histogram of Close Market Value - XRP Daily")
plt.grid()
plt.show()
